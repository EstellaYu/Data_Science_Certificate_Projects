# %% [markdown]
# # Weather API
# ----
#
# ### Description
# *  Latitute and Longitute coordinates will be generated from random number generation
# *  Make citipy API calls based on the (lat, lng), and find at least 500 unique cities
# *  For each city in the list, make OpenWeatherMap API call and obtain the current weather information
#        * organize result in DataFrame
#        * store result in csv.
# * Plot results based on the lattitude
#        * Temperature (F)
#        * Humidity (%)
#        * Cloudiness (%)
#        * Wind Speed (mph)
#
# ### Data
# * (Lat, Lng) corrdintates: from random number generation
# * City names: citipy API
# * City weather: OpenWeatherMap API

# %% [markdown]
# ### Conclusion:
# 1. (`max Temperature (F)` vs. lattitude): In general, max temperature is `higher near the Equater` (as expeted). However,
#     * the temperature curve shifted right, meaning the `temperature is `**`higher`**` in the Northern Hemisphere`.
#     * the `temperature difference` between the `Northern` and `Southern Hemisphere` **`increases`** as the absolute lattitude increases
#
#
# 2. (`Humidity (%)` vs. Lattitude): Overall, the humidity is relatively high globally:
#     * With an average ~ 60%
#     * Within the ~500 cities found, only ~20 cities have humidity less than 20%
#
#
# 3. `Cloudiness` is distributed relativly evenly, with many cities either having 0% (sunny) or 100% cloudiness
#
#
# 4. (`Wind Speed (mph)` vs. Lattitude): Overall, the wind speed is not very high globally:

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
#from api_keys import api_key
api_key = 'e350ecd0f8457e05a2d7e54f90968b59'
import openweathermapy

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# pprint
from pprint import pprint

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=lat_range[0], high=lat_range[1], size=1500)
lngs = np.random.uniform(low=lng_range[0], high=lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print("There are {} cities found from random geo-coordinates.".format(len(cities)))
# Out:
# There are 616 cities found from random geo-coordinates.

# %% [markdown]
# ### OpenWeatherMap API Calls
#
# * Loop though each city on the cities list
# * Perform a (current) weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#     * Note: including `end = '\r'` can override the previous line, which can make the output much cleaner

# %%
# convert the time returned(in seconds) to meaningful time expression
def convert_time(sec):
    order = [ -2, 1, 2, -1, 0]
    local_time = time.ctime(sec).split(" ")
    order_time = [local_time[i] for i in order]
    return f"{order_time[0]} {order_time[1]}/{order_time[2]}/{order_time[3]} ({order_time[4]})"

# %%
# Compose url 
unit = "Imperial"
base_url = f"http://api.openweathermap.org/data/2.5/weather?"
param = {"appid" : api_key,
         "units" : unit}

# Initiate DataFrame
city_weather_now_df = pd.DataFrame(columns=["City",
                                            "Country",
                                            "Lat",
                                            "Lng",
                                            "Max Temp (F)",
                                            "Cloudiness (%)",
                                            "Humidity (%)",
                                            "Wind Speed (mph)",
                                            "Data Retrieved Time"])

# Begin printing the information 
print("Beginning Data Retrieval")
print("----------------------------------------------------------------------------------")

# Loop through the cities, find the cities that OpenWeatherMap can find 
# and store the information to the DataFrame
i = 0
not_found = 0
for city in cities:
    param["q"] = city
    data = requests.get(base_url, params=param).json()
    
    try:
        city_weather_now_df.loc[i, "City"] = data["name"]
        city_weather_now_df.loc[i, "Country"] = data["sys"]["country"]
        city_weather_now_df.loc[i, "Lat"] = data["coord"]["lat"]
        city_weather_now_df.loc[i, "Lng"] = data["coord"]["lon"]
        city_weather_now_df.loc[i, "Max Temp (F)"] = data["main"]["temp_max"]
        city_weather_now_df.loc[i, "Cloudiness (%)"] = data["clouds"]["all"]
        city_weather_now_df.loc[i, "Humidity (%)"] = data["main"]["humidity"]
        city_weather_now_df.loc[i, "Wind Speed (mph)"] = data["wind"]["speed"]
        city_weather_now_df.loc[i, "Data Retrieved Time"] = convert_time(data['dt'])
        i += 1
        print("Processing Record {:3d}/{} | {:20s}\t(# cities not found: {:3d})        ".format(i,
                                                                                         len(cities),
                                                                                         data['name'],
                                                                                         not_found))
              #, end='\r')
              # uncomment this line for clean output
    except KeyError:
        print("City not found. Skipping...{:28s}\t(# cities not found: {:3d})          ".format(" ",
                                                                                                not_found + 1))
              # ,end='\r')
              # uncomment this line for clean output
        not_found += 1

print("\n")
print(f"""
----------------------------------------------------------------------------------
Data Retrieval Complete  
{len(city_weather_now_df)} cities' weather data collected
----------------------------------------------------------------------------------""")
# Out:
# Beginning Data Retrieval
# ----------------------------------------------------------------------------------
# Processing Record   1/616 | Bara                	(# cities not found:   0)
# City not found. Skipping...                            	(# cities not found:   1)
# Processing Record   2/616 | Nantucket           	(# cities not found:   1)
# Processing Record   3/616 | Tabou               	(# cities not found:   1)
# Processing Record   4/616 | Thompson            	(# cities not found:   1)
# Processing Record   5/616 | Saint-Pierre        	(# cities not found:   1)
# Processing Record   6/616 | Pedregulho          	(# cities not found:   1)
# Processing Record   7/616 | Albany              	(# cities not found:   1)
# Processing Record   8/616 | Hermanus            	(# cities not found:   1)
# Processing Record   9/616 | Norman Wells        	(# cities not found:   1)
# Processing Record  10/616 | Vaini               	(# cities not found:   1)
# Processing Record  11/616 | Saint-Augustin      	(# cities not found:   1)
# Processing Record  12/616 | Khatanga            	(# cities not found:   1)
# City not found. Skipping...                            	(# cities not found:   2)
# Processing Record  13/616 | Mataura             	(# cities not found:   2)
# Processing Record  14/616 | Kodiak              	(# cities not found:   2)
# Processing Record  15/616 | Meulaboh            	(# cities not found:   2)
# Processing Record  16/616 | Ribeira Grande      	(# cities not found:   2)
# Processing Record  17/616 | Touros              	(# cities not found:   2)
# Processing Record  18/616 | Nikolskoye          	(# cities not found:   2)
# Processing Record  19/616 | Mar del Plata       	(# cities not found:   2)
# City not found. Skipping...                            	(# cities not found:   3)
# Processing Record  20/616 | Mahebourg           	(# cities not found:   3)
# Processing Record  21/616 | Castro              	(# cities not found:   3)
# Processing Record  22/616 | Talnakh             	(# cities not found:   3)
# Processing Record  23/616 | Silute              	(# cities not found:   3)
# Processing Record  24/616 | Lebu                	(# cities not found:   3)
# Processing Record  25/616 | Provideniya         	(# cities not found:   3)
# Processing Record  26/616 | Bluff               	(# cities not found:   3)
# Processing Record  27/616 | Severo-Kurilsk      	(# cities not found:   3)
# Processing Record  28/616 | Punta Arenas        	(# cities not found:   3)
# Processing Record  29/616 | Saint George        	(# cities not found:   3)
# Processing Record  30/616 | Atuona              	(# cities not found:   3)
# Processing Record  31/616 | Yellowknife         	(# cities not found:   3)
# Processing Record  32/616 | Houma               	(# cities not found:   3)
# City not found. Skipping...                            	(# cities not found:   4)
# Processing Record  33/616 | Saldanha            	(# cities not found:   4)
# Processing Record  34/616 | Miri                	(# cities not found:   4)
# Processing Record  35/616 | Port Alfred         	(# cities not found:   4)
# Processing Record  36/616 | Alice Springs       	(# cities not found:   4)
# Processing Record  37/616 | Mehamn              	(# cities not found:   4)
# Processing Record  38/616 | Lompoc              	(# cities not found:   4)
# Processing Record  39/616 | New Norfolk         	(# cities not found:   4)
# Processing Record  40/616 | Victoria            	(# cities not found:   4)
# Processing Record  41/616 | Bambous Virieux     	(# cities not found:   4)
# City not found. Skipping...                            	(# cities not found:   5)
# Processing Record  42/616 | Padang              	(# cities not found:   5)
# Processing Record  43/616 | Dunedin             	(# cities not found:   5)
# Processing Record  44/616 | Ancud               	(# cities not found:   5)
# Processing Record  45/616 | Hayrabolu           	(# cities not found:   5)
# Processing Record  46/616 | Pevek               	(# cities not found:   5)
# Processing Record  47/616 | Upernavik           	(# cities not found:   5)
# Processing Record  48/616 | Leningradskiy       	(# cities not found:   5)
# Processing Record  49/616 | Black River         	(# cities not found:   5)
# Processing Record  50/616 | Bandarbeyla         	(# cities not found:   5)
# Processing Record  51/616 | Massakory           	(# cities not found:   5)
# City not found. Skipping...                            	(# cities not found:   6)
# City not found. Skipping...                            	(# cities not found:   7)
# Processing Record  52/616 | Cueramaro           	(# cities not found:   7)
# Processing Record  53/616 | Dikson              	(# cities not found:   7)
# Processing Record  54/616 | Jamestown           	(# cities not found:   7)
# Processing Record  55/616 | Puerto Ayora        	(# cities not found:   7)
# Processing Record  56/616 | Hobart              	(# cities not found:   7)
# Processing Record  57/616 | Gizo                	(# cities not found:   7)
# Processing Record  58/616 | Creel               	(# cities not found:   7)
# Processing Record  59/616 | Xichang             	(# cities not found:   7)
# Processing Record  60/616 | Cape Town           	(# cities not found:   7)
# Processing Record  61/616 | Fuengirola          	(# cities not found:   7)
# Processing Record  62/616 | East London         	(# cities not found:   7)
# Processing Record  63/616 | Marzuq              	(# cities not found:   7)
# Processing Record  64/616 | Sisimiut            	(# cities not found:   7)
# Processing Record  65/616 | Rikitea             	(# cities not found:   7)
# Processing Record  66/616 | Noumea              	(# cities not found:   7)
# Processing Record  67/616 | Waipawa             	(# cities not found:   7)
# Processing Record  68/616 | Kapaa               	(# cities not found:   7)
# Processing Record  69/616 | Yenagoa             	(# cities not found:   7)
# Processing Record  70/616 | Sheridan            	(# cities not found:   7)
# Processing Record  71/616 | Barrow              	(# cities not found:   7)
# City not found. Skipping...                            	(# cities not found:   8)
# Processing Record  72/616 | Ngunguru            	(# cities not found:   8)
# City not found. Skipping...                            	(# cities not found:   9)
# Processing Record  73/616 | Esperance           	(# cities not found:   9)
# Processing Record  74/616 | Rajpipla            	(# cities not found:   9)
# Processing Record  75/616 | Qaanaaq             	(# cities not found:   9)
# Processing Record  76/616 | Ushuaia             	(# cities not found:   9)
# Processing Record  77/616 | Busselton           	(# cities not found:   9)
# City not found. Skipping...                            	(# cities not found:  69)
# Processing Record 532/616 | Oranjemund          	(# cities not found:  69)
# Processing Record 533/616 | Plouzane            	(# cities not found:  69)
# Processing Record 534/616 | Kamenka             	(# cities not found:  69)
# Processing Record 535/616 | Port-Cartier        	(# cities not found:  69)
# Processing Record 536/616 | Kahramanmaras       	(# cities not found:  69)
# Processing Record 537/616 | Awbari              	(# cities not found:  69)
# Processing Record 538/616 | Hattiesburg         	(# cities not found:  69)
# Processing Record 539/616 | Bayir               	(# cities not found:  69)
# Processing Record 540/616 | Pamulang            	(# cities not found:  69)
# Processing Record 541/616 | Quang Ngai          	(# cities not found:  69)
# Processing Record 542/616 | Kattivakkam         	(# cities not found:  69)
# Processing Record 543/616 | Koindu              	(# cities not found:  69)
# City not found. Skipping...                            	(# cities not found:  70)
# Processing Record 544/616 | La Macarena         	(# cities not found:  70)
# Processing Record 545/616 | Lahij               	(# cities not found:  70)
# Processing Record 546/616 | Vikulovo            	(# cities not found:  70)
#
#
#
# ----------------------------------------------------------------------------------
# Data Retrieval Complete
# 546 cities' weather data collected
# ----------------------------------------------------------------------------------

# %% [markdown]
# ### Save data stored in DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_now_df.count()
# Out:
# City                   546
# Country                546
# Lat                    546
# Lng                    546
# Max Temp (F)           546
# Cloudiness (%)         546
# Humidity (%)           546
# Wind Speed (mph)       546
# Data Retrieved Time    546
# dtype: int64

# %%
city_weather_now_df.head()
# Out:
#            City Country    Lat    Lng Max Temp (F) Cloudiness (%)  \
# 0          Bara      NG  10.41   10.6        87.61             40
# 1     Nantucket      US  41.28  -70.1        73.99             90
# 2         Tabou      CI   4.42  -7.36        80.77             47
# 3      Thompson      CA  55.74 -97.86         60.8             40
# 4  Saint-Pierre      FR  48.95   4.24           95              0
#
#   Humidity (%) Wind Speed (mph)         Data Retrieved Time
# 0           54            10.96  11:53:01 Jun/27/2019 (Thu)
# 1          100              4.7  11:53:01 Jun/27/2019 (Thu)
# 2           74             7.78  11:53:01 Jun/27/2019 (Thu)
# 3           59              4.7  11:53:01 Jun/27/2019 (Thu)
# 4           46            16.11  11:53:01 Jun/27/2019 (Thu)

# %%
city_weather_now_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Plot `Max Temperature`, `Humidity`, `Cloudiness`, and `Wind Speed` across all `Latitude`.
# * Save the plotted figures as .pngs.

# %%
font = 15
date = city_weather_now_df['Data Retrieved Time'][0].split(' ')[1] 

# define a functino that deals with the plotting style
def plot_setting(x, y, color, alpha):
    plt.figure(figsize=(8,5))
    plt.scatter(x, y, facecolor = color, edgecolor = 'k', alpha = alpha)
    xrange = max(x) - min(x)
    yrange = max(y) - min(y)
    plt.xlim(min(x) - xrange/5, max(x) + xrange/5)
    plt.ylim(min(y) - yrange/5, max(y) + yrange/5)
    plt.grid(True)

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# define x, y axis
col = ["Lat", "Max Temp (F)"]

x = city_weather_now_df[col[0]]
y = city_weather_now_df[col[1]]

# plot Latitude vs. Max Temperature
color = (1, 0.4, 0)
alpha = 0.8
plot_setting(x,y, color, alpha)
plt.xlabel("Latitude", fontsize = font)
plt.ylabel("Max Temperature (F)", fontsize = font)
plt.title(f"City Latitude vs. Max Temparature ({date})\n", fontsize = font)
# plt.savefig("output_data/max_temp.png")
plt.show()

# %%
# Create a temp_df DataFrame for more indepth temperature analysis
cols = ["City", "Country", "Lat", "Max Temp (F)"]
temp_df = city_weather_now_df[cols].copy()
temp_df["Lat"] = temp_df["Lat"].astype("float")
temp_df["Max Temp (F)"] = temp_df["Max Temp (F)"].astype("float")

# ------------- binning------------- 
# bins
bin_width = 5
lat_min = round(temp_df["Lat"].min()) + bin_width
lat_max = round(temp_df["Lat"].max())

# to ensure the bins are symmetric around Equater
if abs(lat_min) > lat_max:
    lat_0 = lat_max
else: 
    lat_0 = -lat_min

bins_pos = list(np.arange(0, lat_0 + 1, bin_width)) 
bins_neg = [-x for x in bins_pos if x != 0]
bins_neg.sort()
bins = ([lat_range[0]] + bins_neg + bins_pos + [lat_range[1]])
print(f"neg_bins:{bins[:len(bins)//2]}\npos_bins:{bins[len(bins)//2 :]}")

# bins label
label_name = [f"({str(bins[i])}, {str(bins[i+1])}]" for i in range(len(bins) -1)]
label_name[0] = f"<= {bins[1]}"
label_name[-1] = f"> {bins[-2]}"

# create new col for binned results
temp_df["Lat_group"] = pd.cut(temp_df["Lat"], bins, labels=label_name)
temp_df.head()
# Out:
# neg_bins:[-90, -50.0, -45.0, -40.0, -35.0, -30.0, -25.0, -20.0, -15.0, -10.0, -5.0]
# pos_bins:[0.0, 5.0, 10.0, 15.0, 20.0, 25.0, 30.0, 35.0, 40.0, 45.0, 50.0, 90]
#            City Country    Lat  Max Temp (F)     Lat_group
# 0          Bara      NG  10.41         87.61  (10.0, 15.0]
# 1     Nantucket      US  41.28         73.99  (40.0, 45.0]
# 2         Tabou      CI   4.42         80.77    (0.0, 5.0]
# 3      Thompson      CA  55.74         60.80        > 50.0
# 4  Saint-Pierre      FR  48.95         95.00  (45.0, 50.0]

# %%
# ------------- groupby, and calculate averege temp ------------- 
lat_temp_df = temp_df.groupby(["Lat_group"]).mean()["Max Temp (F)"]
avg_lat = ([(lat_min + bins[1])/2] + 
           [(bins[i] + bins[i+1])/2 for i in range(1, len(bins)-2)] + 
           [(lat_max + bins[-2])/2])
lat_temp_df = lat_temp_df.reset_index()
lat_temp_df["avg_lat"] = pd.Series(avg_lat)
lat_temp_df.head()
# Out:
#         Lat_group  Max Temp (F)  avg_lat
# 0        <= -50.0     31.100000    -50.0
# 1  (-50.0, -45.0]     40.083750    -47.5
# 2  (-45.0, -40.0]     50.068333    -42.5
# 3  (-40.0, -35.0]     50.033000    -37.5
# 4  (-35.0, -30.0]     57.548636    -32.5

# %%
# Plot Tempareture Difference in Northern and Southern Hemisphere
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

# Plot temperature of all cities
ax1
# define x, y axis
col = ["Lat", "Max Temp (F)"]

x = city_weather_now_df[col[0]]
y = city_weather_now_df[col[1]]
color = 'red'
alpha = 0.15
ax1.scatter(x, y,facecolor = color, edgecolor = 'k', alpha = 0.15)
xrange = max(x) - min(x)
yrange = max(y) - min(y)
ax1.set_xlim(min(x) - xrange/5, max(x) + xrange/5)
ax1.set_ylim(min(y) - yrange/5, max(y) + yrange/5)

# plot average Temperature, every 5 degree lat
col = ["avg_lat", "Max Temp (F)"]
x = lat_temp_df[col[0]]
y = lat_temp_df[col[1]]
ax1.scatter(x, y, facecolor = 'blue', edgecolor = 'k', alpha = 1, 
            label = f"Average Temp (by Lat: {bin_width} degree)")

ax1.grid(True)
ax1.set_xlabel("Latitude", fontsize = font)
ax1.set_ylabel("Max Temperature (F)", fontsize = font)
ax1.legend(loc = "upper left")
ax1.set_title(f"City Latitude vs. Max Temparature ({date})\n", fontsize = font)


# Plot temperature difference between NORTHERN and SOUTHERN hemispheres
rows = lat_temp_df.count()["avg_lat"]
diff = []
for i in range(rows//2):
    df = (lat_temp_df.iloc[-i-1, 1] - lat_temp_df.iloc[i, 1])
    diff.append(df)
    
ax2.scatter(bins_pos, diff[::-1], facecolor = 'green', label = "Temp diff")
ax2.grid(True)
ax2.set_xlabel("Absolute Value of Latitude", fontsize = font)
ax2.set_ylabel("Temperature Difference (F)", fontsize = font)
ax2.set_title(f"Temp Difference btw Northern and Southern hemisphere\n", fontsize = font)

plt.tight_layout
plt.savefig("output_data/max_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# define x, y axis
# city_weather_now_df['Humidity (%)'] = city_weather_now_df['Humidity (%)'< 20]
print("Average Humidity: {:.2f} %".format(city_weather_now_df['Humidity (%)'].mean()))
print("Number of city with less than 20% humidity: {}".format(city_weather_now_df[city_weather_now_df['Humidity (%)'] 
                                                                          < 20].count()['City']))

col = ["Lat", "Humidity (%)"]

x = city_weather_now_df[col[0]]
y = city_weather_now_df[col[1]]

# plot Latitude vs. Humidity
color = (0.68, 0.9, 1)
alpha = 0.8
plot_setting(x,y,color,alpha)
plt.xlabel("Latitude", fontsize = font)
plt.ylabel(col[1], fontsize = font)
plt.title(f"City Latitude vs. Humidity ({date})\n", fontsize = font)
plt.savefig("output_data/humidity.png")
plt.show()
# Out:
# Average Humidity: 65.70 %
# Number of city with less than 20% humidity: 29

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# define x, y axis
col = ["Lat", "Cloudiness (%)"]

x = city_weather_now_df[col[0]]
y = city_weather_now_df[col[1]]

# plot Latitude vs. Cloudiness
color = (0.7, 0.7, 0.8)
alpha = 0.8
plot_setting(x,y,color,alpha)
plt.xlabel("Latitude", fontsize = font)
plt.ylabel(col[1], fontsize = font)
plt.title(f"City Latitude vs. Cloudiness ({date})\n", fontsize = font)
plt.savefig("output_data/cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# define x, y axis
col = ["Lat", "Wind Speed (mph)"]

x = city_weather_now_df[col[0]]
y = city_weather_now_df[col[1]]

# plot Latitude vs. Wind Speed
color = (1, 1, 0.6)
alpha = 0.8
plot_setting(x,y,color,alpha)
plt.xlabel("Latitude", fontsize = font)
plt.ylabel(col[1], fontsize = font)
plt.title(f"City Latitude vs. Wind Speed ({date})\n", fontsize = font)
plt.savefig("output_data/wind_speed.png")
plt.show()
